# %%
import numpy as np
from helpers import load_csv_data

# %%
#Load data
y_train, x_train, x_test, train_ids, test_ids = load_csv_data("dataset")

print(x_train.shape)
print(y_train.shape)
# Out:
# (328135, 321)
# (328135,)
